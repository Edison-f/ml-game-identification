# %% [markdown]
# ## Model Input Sizes

# %%
width = 1280
height = 720

# %% [markdown]
# ## Process Images

# %%
# Iterate over each file in /processing/input
    # Normalize it to the correct dimensions using PIL

# %% [markdown]
# ## Process Videos

# %%
# Probably use a bash sc
